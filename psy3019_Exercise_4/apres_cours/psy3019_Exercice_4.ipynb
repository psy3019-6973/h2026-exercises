# %% [markdown]
# # Exercice 4 : Introduction au Bash et Manipulation de fichiers
#
# Cet exercice vise à tester vos compétences en ligne de commande (Bash) pour la navigation, la manipulation de fichiers et l'automatisation simple.
#
# ## Contexte
# Pierre-Antoine (P-A), un étudiant au doctorat en psychologie, a besoin d'aide pour organiser les données de son projet de thèse. Son dépôt contient :
# 1. Des données brutes (`bids_stroop_dataset/`)
# 2. Un script d'analyse (`process_data.py`)
# 3. Un fichier de dépendances (`environment_shell.yml`) pour votre environnement
# 4. Le ficher `README.md`
#
# ![photo_profil_PA.png](data:image/png;base64,...)
#
# ⚠️ **Instructions importantes** :
# - **Format des cellules** : Utilisez le "magic command" `!` ou `%%bash` pour exécuter du Bash dans les cellules Python.
# - **Autocorrection** : Les tests automatisés vérifieront l'existence des fichiers, leurs emplacements et leurs contenus après exécution. Assurez-vous de respecter scrupuleusement les noms de fichiers et dossiers demandés.
# - **Total** : 50 points.

# %% [markdown]
# ## ⚠ Veuillez exécuter cette cellule avant de démarrer. Il est essentiel pur assurer que tous les fichiers nécessaires existent dans la bonne place.

# %%
# Supprimer les fichiers s'ils existent déjà
# !rm -rf bids_stroop_dataset
# !rm -f process_data.py
# !rm -f environment_shell.yml
# !rm -f README.md

# Télécharger le dossier bids_stroop_dataset
# !wget https://github.com/psy3019-6973/h2026-exercises/raw/refs/heads/main/psy3019_Exercise_4/apres_cours/bids_stroop_dataset.zip
# !unzip bids_stroop_dataset.zip
# !rm bids_stroop_dataset.zip

# Télécharger process_data.py
# !wget https://raw.githubusercontent.com/psy3019-6973/h2026-exercises/refs/heads/main/psy3019_Exercise_4/apres_cours/process_data.py

# Télécharger environment_shell.yml
# !wget https://raw.githubusercontent.com/psy3019-6973/h2026-exercises/refs/heads/main/psy3019_Exercise_4/apres_cours/environment_shell.yml

# Télécharger README.md
# !wget https://raw.githubusercontent.com/psy3019-6973/h2026-exercises/refs/heads/main/psy3019_Exercise_4/apres_cours/README.md

# %% [markdown]
# # Question 1 : Visualisation de l'arborescence (2 points)
#
# Pour comprendre la structure actuelle du dépôt de P-A, utilisez la commande permettant de visualiser le dossier courant sous forme d'arbre hiérarchique.

# %%
# Réponse 1
# Votre commande ici (ex: ! commande)
! ...

# %% [markdown]
# # Question 2 : Inspection de fichier (2 points)
#
# Vous souhaitez voir quelles sont les librairies requises dans `requirements.txt`, mais P-A vous indique que seules les **3 premières lignes** sont importantes.
#
# Utilisez la commande appropriée pour afficher uniquement les 3 premières lignes de ce fichier.

# %%
# Réponse 2
! ...

# %% [markdown]
# # Question 3 : Lecture de fichier (2 points)
#
# Afin de mieux comprendre le projet de P-A, vous souhaitez lire tout le `README.md`, sans inonder votre terminal de texte.
#
# Ouvrez votre terminal et utilisez la commande appropriée (celle qui permet de naviguer dans le texte page par page). Une fois que vous êtes sûr de votre réponse, collez la commande dans la cellule ci-dessous.

# %%
# Réponse 3
! ...

# %% [markdown]
# # Question 4 : Recherche de fichiers par motif (4 points)
#
# P-A a oublié de remplacer un code temporaire par le vrai numéro de sujet dans l'un des fichiers. Il sait que le fichier contient le motif "XX" dans son nom.
#
# Utilisez la commande `find` pour localiser le fichier dont le nom contient "XX" à l'intérieur du dossier courant (`.`).

# %%
# Réponse 4
! ...

# %% [markdown]
# # Question 5 : Identification de fichiers mal placés (5 points)
#
# P-A a déplacé accidentellement des fichiers dans son jeu de données `bids_stroop_dataset/`. Il ne sait pas où ils sont.
#
# En utilisant la commande `ls` avec des **wildcards** (jokers `*`), affichez le contenu de tous les sous-dossiers (profondeur 3 : dataset -> sujet -> type_donnée -> fichier) pour repérer visuellement les fichiers qui ne semblent pas être à leur place (ex: un sujet 05 dans le dossier du sujet 04).

# %%
# Réponse 5
! ...

# %% [markdown]
# # Question 6 : Création de sauvegarde (5 points)
#
# Avant de corriger les erreurs, il est prudent de faire une copie de sécurité.
#
# 1. Créez un dossier nommé `backup_stroop_dataset`.
# 2. Copiez **tout le contenu** du dossier `bids_stroop_dataset` à l'intérieur de `backup_stroop_dataset`.

# %%
# Réponse 6
! ...

# %% [markdown]
# # Question 7 : Renommer un fichier (5 points)
#
# Vous avez identifié (à la Q4) le fichier contenant "XX". Il s'agit en réalité d'un sujet spécifique.
#
# Écrivez la commande pour renommer ce fichier spécifique :
# `sub-XX_task-stroop.csv`

# %%
# Réponse 7
! ...

# %% [markdown]
# # Question 8 : Déplacer des fichiers (5 points)
#
# Vous avez remarqué (à la Q5) que des fichiers appartenant au sujet `sub-05` se trouvent par erreur dans le dossier du sujet `sub-04`.
#
# Utilisez une seule commande `mv` avec un wildcard (`*`) pour déplacer tous les fichiers contenant "sub-05" (qui sont actuellement dans le dossier de `sub-04`) vers le dossier du sujet `sub-05`.

# %%
# Réponse 8
! ...

# %% [markdown]
# # Question 9 : Suppression de dossier (5 points)
#
# Maintenant que les données originales sont corrigées et propres, la sauvegarde n'est plus nécessaire.
#
# Supprimez le dossier `backup_stroop_dataset` et tout son contenu.

# %%
# Réponse 9
! ...

# %% [markdown]
# # Question 10 : Archivage sélectif avec Rsync (5 points)
#
# Un collègue souhaite obtenir uniquement les données anatomiques (`anat/`).
#
# 1. Créez un dossier `stroop_anat_dataset`.
# 2. Utilisez la commande `rsync` pour copier **uniquement** les dossiers `anat` (et leur contenu) depuis `bids_stroop_dataset` vers `stroop_anat_dataset`.
# 3. Utilisez l'option pour compresser les données pendant le transfert (`-z`).
#
# *Indice : Vous devrez utiliser `--include` et `--exclude`.*

# %%
# Réponse 10
! ...

# %% [markdown]
# # Question 11 : Automatisation (10 points)
#
# P-A souhaite que son analyse soit reproductible. Vous devez créer un script shell nommé `run_all.sh`.
#
# **Instructions :**
# 1. Utilisez votre **terminal** et la commande `nano run_all.sh` pour créer et éditer votre script.
# 2. Dans ce script, écrivez les 4 lignes suivantes :
#    - Lancer le script python `process_data.py`. (Il génère `resultat[1-5].txt`).
#    - Créer un fichier vide nommé `resultats_finaux.txt`.
#    - Chercher toutes les lignes qui commencent ET finissent par `#` dans les fichiers résultats, et les sauvegarder dans `resultats_finaux.txt`.
#    - Afficher le contenu de `resultats_finaux.txt`.
# 3. Une fois le fichier créé, exécutez la cellule ci-dessous pour changer les permissions et lancer le script.

# %%
# Réponse 11
! ...

# Exécution du script
! ... run_all.sh
! ./run_all.sh
