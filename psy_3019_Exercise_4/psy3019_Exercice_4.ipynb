# %% [markdown]
# # Exercice d'introduction au Bash
#
# Bonjour et bienvenue dans cet exercice Bash !<br>
# Si vous êtes en train de lire ces instructions, vous avez bien cloné le dépôt GitHub : https://github.com/psy3019-6973/h2026-exercises.git <br>
# Ce dépôt est utilisé par Pierre-Antoine (P-A) : un étudiant au doctorat en psychologie à l'Université de Montréal. Il lui sert à faire les analyses de son projet de thèse. Le dépôt contient des données (bids_stroop_dataset/), un script python (process_data.py) ainsi qu'un fichier requirement.txt, qui liste les librairies nécessaires aux analyses.
#
#
# Photo de P-A:
#
#
# ![Photo de P-A](photo_profil_PA.png)
#
#
# P-A a quelques problèmes avec sont dépôt GitHub et a besoin de votre aide (faute d'avoir suivi le cours PSY-3019).

# %% [markdown]
# La première étape est de créer un environnement conda avec les dépendances nécessaires, pour cela exécutez la cellule ci-dessous.

# %%
! conda create -n intro_bash -p python=3.10
! conda activate intro_bash
! pip install -r requirements.txt

# %% [markdown]
# Avant de commencer les exercices, vous devez savoir comment excuter des commandes Bash dans un notebook Python. En réalité, il n'y a rien de plus simple :
# - Utiliser un kernel Bash
# - Écrire %%bash au début de chaque cellule
# - Écrire ! au début de chaque ligne
#
# Pour les besoins de l'exercice, on vous suggère d'utiliser le point d'exclamation.

# %% [markdown]
# ## Consigne 1 :
# Pour mieux comprendre le dépôt de P-A, utilisez une commande qui vous permettra de le visualiser sous forme d'arbre.

# %%
# Commande attendue -> ! tree
! ...

# %% [markdown]
# ## Tests 1 :
# 1. Vérifier si la commande contient bien tree. Aussi non l'étudiant n'utilise pas la bonne fonction.
# 2. Vérifier que la commande ne contient que tree. Aussi non l'étudiant ne regarde pas le bon dossier.

# %% [markdown]
# # Consigne 2 :
# Par curiosité, vous souhaitez voir ce qu'il y a dans le fichier requirements.txt. P-A vous indique que seules les 3 premières lignes sont importantes. Lisez la documentation de head et utilisez l'option appropriée pour afficher les 3 premières lignes du fichier requirements.txt

# %%
# Commande attendue -> ! head -n 3 requirements.txt ou ! head --lines 3 requirements.txt
! head --help
! head ... requirements.txt

# %% [markdown]
# # Test 2 :
# 1. Vérifier que la commande contient :' 3 '. Aussi non l'étudiant ne regarde pas le bon nombre de ligne
# 2. Vérifier que la sortie est : <br>
# jupyterlab<br>
# ipykernel<br>
# numpy
#
# Aussi non l'étudiant n'utilise pas la bonne option.

# %% [markdown]
# # Consigne 3 :
# Afin de mieux comprendre le projet de P-A, vous souhaitez lire tout le README.md, sans inonder votre terminal de texte. Ouvrez votre terminal et utilisez la commande appropriée. Une fois que vous êtes sûr de votre réponse, collez la commande dans la cellule ci-dessous.

# %%
# Commande attendue -> ! less README.md
! ... README.md

# %% [markdown]
# ## Test 3 :
# Vérifier que la commande est : less README.md. Aussi non l'étudiant n'utilise pas la bonne commande.

# %% [markdown]
# # Consigne 4 :
# P-A commence à vous expliquer ses problèmes... Il a oublié de mentionner le numéro de sujet dans le nom de l'un des fichiers de la base de données. Il vous apprend que par défaut le numéro de sujet d'un participant est noté XX dans les noms de fichier. Utilisez la commande qui vous permettra de trouver le fichier avec le pattern "XX" dans son nom.

# %%
# Commande attendue -> ! find . -name *XX*
! ...

# %% [markdown]
# ## Tests 4 :
# 1. Vérifier qu'il y a find dans la commande. Aussi non l'étudiant n'utilise pas la bonne commande.
# 2. Vérifier qu'il y a -name dans la commande. Aussi non l'étudiant n'utilise pas la bonne option.
# 3. Vérifier qu'il y a \*XX\* dans la commande. Aussi non l'étudiant n'utilise pas le bon pattern.
# 4. Vérifier que la sortie soit : ./bids_stroop_dataset/sub-02/beh/sub-XX_task-stroop.csv. Aussi non l'étudiant n'indique pas le bon chemin.

# %% [markdown]
# # Consigne 5
# Par la suite, P-A vous apprend qu'il a déplacé des fichiers dans sa base de données (bids_stroop_dataset/), mais il ne sait pas lesquels et où ils se situent. En utilisant la commande ls, afficher tous les chemins de la base de données et trouver les fichiers mal placés.

# %%
# Commande attendue -> ! ls bids_stroop_dataset/*/*/*
! ls ...
# Out:
# bids_stroop_dataset/sub-01/anat/sub-01_task-stroop_T1w.nii.gz
# bids_stroop_dataset/sub-01/beh/sub-01_task-stroop.csv
# bids_stroop_dataset/sub-01/func/sub-01_task-stroop_bold.nii.gz
# bids_stroop_dataset/sub-02/anat/sub-02_task-stroop_T1w.nii.gz
# bids_stroop_dataset/sub-02/beh/sub-XX_task-stroop.csv
# bids_stroop_dataset/sub-02/func/sub-02_task-stroop_bold.nii.gz
# bids_stroop_dataset/sub-03/anat/sub-03_task-stroop_T1w.nii.gz
# bids_stroop_dataset/sub-03/beh/sub-03_task-stroop.csv
# bids_stroop_dataset/sub-03/func/sub-03_task-stroop_bold.nii.gz
# bids_stroop_dataset/sub-04/anat/sub-04_task-stroop_T1w.nii.gz
# bids_stroop_dataset/sub-04/anat/sub-05_task-stroop_T1w.nii.gz
# bids_stroop_dataset/sub-04/beh/sub-04_task-stroop.csv
# bids_stroop_dataset/sub-04/beh/sub-05_task-stroop.csv
# bids_stroop_dataset/sub-04/func/sub-04_task-stroop_bold.nii.gz
# bids_stroop_dataset/sub-04/func/sub-05_task-stroop_bold.nii.gz

# %% [markdown]
# ## Tests 5 :
# 1. Vérifier que la commande contient ls. Aussi non l'étudiant n'utilise pas la bonne commande
# 2. Vérifier que la commande contient bids_stroop_dataset/. Aussi non l'étudiant ne regarde pas seulement ce qu'il y a dans le jeu de données bids_stroop_dataset
# 3. Vérifier que la sortie est :
# bids_stroop_dataset/sub-01/anat/sub-01_task-stroop_T1w.nii.gz <br>
# bids_stroop_dataset/sub-01/beh/sub-01_task-stroop.csv <br>
# bids_stroop_dataset/sub-01/func/sub-01_task-stroop_bold.nii.gz <br>
# bids_stroop_dataset/sub-02/anat/sub-02_task-stroop_T1w.nii.gz <br>
# bids_stroop_dataset/sub-02/beh/sub-XX_task-stroop.csv <br>
# bids_stroop_dataset/sub-02/func/sub-02_task-stroop_bold.nii.gz <br>
# bids_stroop_dataset/sub-03/anat/sub-03_task-stroop_T1w.nii.gz <br>
# bids_stroop_dataset/sub-03/beh/sub-03_task-stroop.csv <br>
# bids_stroop_dataset/sub-03/func/sub-03_task-stroop_bold.nii.gz <br>
# bids_stroop_dataset/sub-04/anat/sub-04_task-stroop_T1w.nii.gz <br>
# bids_stroop_dataset/sub-04/anat/sub-05_task-stroop_T1w.nii.gz <br>
# bids_stroop_dataset/sub-04/beh/sub-04_task-stroop.csv <br>
# bids_stroop_dataset/sub-04/beh/sub-05_task-stroop.csv <br>
# bids_stroop_dataset/sub-04/func/sub-04_task-stroop_bold.nii.gz <br>
# bids_stroop_dataset/sub-04/func/sub-05_task-stroop_bold.nii.gz
# Aussi non l'étudiantle n'utilise pas le bon parttern.

# %% [markdown]
# # Consigne 6
# Avant de rectifier les erreurs de P-A, il vaut mieux prendre des précautions avec ses données. Pour être sûr de ne rien perdre, créez un dossier backup_stroop_dataset/, puis copiez les données de P-A dans ce dossier backup.
#
# ⚠️ On veut copier le contenu de la base de données, sans le dossier bids_stroop_dataset/

# %%
# Commande attendue -> mkdir backup_stroop_dataset && cp -r bids_stroop_dataset/* backup_stroop_dataset/
! ... backup_stroop_dataset/
! ...

# %% [markdown]
# ## Tests 6 :
# 1. Vérifier que la commande comprend : mkdir backup_stroop_dataset. Aussi non l'étudiant n'utilise pas la bonne commande pour créer le dossier backup_stroop_dataset
# 2. Vérifier que le dossier backup_stroop_dataset est crée. Aussi non l'étudiant n'a pas créer le bon dossier.
# 3. Vérifier que cp est compris dans la commande. Aussi non l'étudiant n'utilise pas la bonne commande pour copier les données.
# 4. Vérifier que les dossier backup_stroop_dataset et bids_stroop_dataset aient le même contenu. Aussi non l'étudiant ne copie pas le bon dossier.

# %% [markdown]
# # Consigne 7 :
# Maintenant qu'une copie de bids_stroop_dataset/ est crée et que vous avez identifié le fichier mal nommé, renommez le avec le bon numéro de participant.

# %%
# Commande attendue -> mv bids_stroop_dataset/sub-02/beh/sub-XX_task-stroop.csv bids_stroop_dataset/sub-02/beh/sub-02_task-stroop.csv
! ...

# %% [markdown]
# ## Tests 7 :
# 1. Vérifier que le mv est présent dans la commande. Aussi non l'étudiant n'utilise pas la bonne commande.
# 2. Vérifier que bids_stroop_dataset/sub-02/beh/sub-XX_task-stroop.csv n'existe plus. Aussi non l'étudiant n'a pas renommé le bon fichier.
# 3. Vérifier que bids_stroop_dataset/sub-02/beh/sub-02_task-stroop.csv existe bien. Aussi non l'étudiant n'a pas bien renommé le fichier.

# %% [markdown]
# # Consigne 8 :
# Pour finir de corriger les erreurs de P-A, il faut déplacer les fichiers mal placés dans leur dossier initial. Occupez-vous-en avec la même commande que pour la consigne précédente.

# %%
# Commande attendue -> mv bids_stroop_dataset/sub-04/*sub-05* bids_stroop_dataset/sub-05/
! ...

# %% [markdown]
# ## Tests 8 :
# 1. Vérifier que les fichiers de sub-05 ne sont plus dans sub-04/. Aussi non l'étudiant n'a pas bougé les bons fichiers.
# 2. Vérifier que les fichiers de sub-05 sont dans sub-05/. Aussi non l'étudiant n'a pas déplacer les fichiers au bon endroit.
# 3. Vérifier que la commande mv est bien utilisée. Aussi non l'étudiant n'a pas utilisé la bonne commande.

# %% [markdown]
# # Consigne 9 :
# Maintenant que l'ordre est rétabli dans la base de données à P-A, supprimez le dossier backup.

# %%
# Commande attendue -> ! rm -r backup_stroop_dataset
! ...

# %% [markdown]
# ## Test 9 :
# Vérifier que la commande est rm -r backup_stroop_dataset. Aussi non l'étudiant n'utilise pas la bonne commande.

# %% [markdown]
# # Consigne 10 :
# P-A vous demande une petite faveur en plus... Un de ses collègue est extrêmement intéressé par les données anatomiques de bids_stroop_dataset/ et souhaiterait que P-A les lui partage. Il voudrait que vous lui montriez une nouvelle commande pour faire une copie de bids_stroop_dataset. Créez un nouveau dossier stroop_anat_dataset, puis faites une copie de bids_stroop_dataset en incluant les dossiers anat/ et en excluant tout le reste. Les fichiers .nii.gz ont tendance à être lourds, utilisez une option afin de les compresser lors de la copie.

# %%
# Commande attendue -> mkdir stroop_anat_dataset && rsync -z --include 'sub*/anat/*' --exclude '*' bids_stroop_dataset/ stroop_anat_dataset/
! ... stroop_anat_dataset/
! ...

# %% [markdown]
# ## Tests 10 :
# 1. Vérifier que mkdir est utilisé. Aussi non, l'étudiant ne créer pas de dossier.
# 2. Vérifier que rsync, -z, exclude et include sont utilisé. Aussi non, l'étudiant n'utilise pas la bonne commande et les bonnes options.
# 3. Vérifier que stroop_anat_dataset/sub*/*/* == bids_stroop_dataset/sub*/anat/*. Aussi non, l'étudiant n'a pas copié le bon contenu.

# %% [markdown]
# # Consigne 11 :
# P-A vous demande un dernier service, en retour vous lui demandez un authorship et il accepte. P-A souhaiterait que son projet soit reproductible et ses analyses automatisées. Pour atteindre cet objectif vous lui proposez de créer un fichier run_all.sh. Dans ce script, il faudra dans un premier temps recréer un environnement conda, l'activer et installer les dépendances avec :
#
# conda create -n stroop_PA_env python=3.10<br>
# conda activate stroop_PA_env<br>
# pip install -r requirements.txt<br>
#
# Il vous restera 4 lignes à écrire, pour:
# 1. Lancer process_data.py. Ce script python créer 5 fichier (resultat1.txt, resultat2.txt, ..., resultat5.txt). Dans ces fichiers, seules les lignes commancant et finissant par '#' sont intéressante pour comprendre le message global du projet.
# 2. Créer un fichier vide nommé resultats_finaux.txt.
# 3. Utiliser une chaîne de commande pour écrir toutes les lignes pertinantes dans resultats_finaux.txt
# 4. Afficher dans le ternimal le contenu de resultats_finaux.txt
#
# Pour ce faire, utiliser votre ternimal et la commande nano run_all.sh pour commencer à éditer votre script.
#
# Avant de lancer votre script dans la cellule ci-dessous, assurez-vous que de changer les autorisations pour que run_all.sh devienne un exécutable.

# %%
# Commande attendue -> chmod +x run_all.sh &&  ./run_all.sh
! chmod ... run_all.sh
! ./run_all.sh

# %% [markdown]
# ## Tests 11 :
# le fichier run_all.sh contient :<br>
# conda create -n bash_exercies_env python=3.10<br>
# conda activate bash_exercies_mon_env<br>
# pip install -r requirements.txt<br>
# python process_data.py<br>
# touch résultats_finaux.txt<br>
# cat resultat1.txt resultat2.txt resultat3.txt resultat4.txt resultat5.txt | grep ‘^#*#$’ > resultats_finaux.txt<br>
# cat resultats_finaux.txt
#
#
# Le ternimal doit contenir :
# <pre>
# ####################################################
# #  _     _                    _                    #
# # | |   (_)                  | |              /    #
# # | |__  _  ___ _ __         | | ___  _   _  __    #
# # | '_ \| |/ _ \ '_ \    _   | |/ _ \| | | |/ _ \  #
# # | |_) | |  __/ | | |  | |__| | (_) | |_| |  __/  #
# # |_.__/|_|\___|_| |_|   \____/ \___/ \__,_|\___|  #
# #                                                  #
# ####################################################
# <pre>
#
# La commande doit contenir chmod +x
